# %% [markdown]
# ## 1. LOAD MUSHROOM DATA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import csv
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import learning_curve
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from numpy import mean
from numpy import std
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import recall_score


data = pd.read_csv("agaricus-lepiota.csv")
df = pd.DataFrame(data=data)
df.rename(columns={' ':' ','p': 'poisonous', 'x': 'cap-shape', 's': 'cap-surface', 'n': 'cap-color', 't': 'bruises?', 'p.1': 'odor', 'f': 'gill-attachment', 'c': 'gill-spacing', 'n.1': 'gill-size', 'k': 'gill-color', 'e': 'stalk-shape', 'e.1': 'stalk-root', 's.1': 'stalk-surface-above-ring', 's.2': 'stalk-surface-below-ring', 'w': 'stalk-color-above-ring', 'w.1': 'stalk-color-below-ring', 'p.2': 'veil-type', 'w.2': 'veil-color', 'o': 'ring-number', 'p.3': 'ring-type', 'k.1': 'spore-print-color', 's.3': 'population', 'u': 'habitat'}, inplace=True)

# %% [markdown]
# ## 1. LOAD IRIS DATA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import csv
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

df_i = pd.read_csv('iris.data')
df_i.to_csv('iris.csv')

data_i = pd.read_csv("iris.csv",names=["sepal_length", "sepal_width", "petal_length", "petal_width", "species"])
df_i = pd.DataFrame(data=data_i)

# %% [markdown]
# ## code explain
# load the data file first <br>
# change it to csv file<br>
# load csv file <br>
# change the data's column to what you want <br>
# make the data into dataframe (use panda) <br>

# %% [markdown]
# ## 2. DRAW MUSHROOM DISTRIBUTION

# %% [markdown]
# ### Show the data distribution by value frequency of every feature MUSHROOM

# %%
sns.catplot(x="poisonous", data=df, kind="count")
sns.catplot(x="cap-shape", data=df, kind="count")
sns.catplot(x="cap-surface", data=df, kind="count")
sns.catplot(x="cap-color", data=df, kind="count")
sns.catplot(x="bruises?", data=df,  kind="count")
sns.catplot(x="odor", data=df, kind="count")
sns.catplot(x="gill-attachment", data=df,  kind="count")
sns.catplot(x="gill-spacing", data=df,  kind="count")
sns.catplot(x="gill-size", data=df,  kind="count")
sns.catplot(x="gill-color", data=df,  kind="count")
sns.catplot(x="stalk-shape", data=df,  kind="count")
sns.catplot(x="stalk-root", data=df, kind="count")
sns.catplot(x="stalk-surface-above-ring", data=df, kind="count")
sns.catplot(x="stalk-surface-below-ring", data=df, kind="count")
sns.catplot(x="stalk-color-above-ring", data=df, kind="count")
sns.catplot(x="stalk-color-below-ring", data=df, kind="count")
sns.catplot(x="veil-type", data=df, kind="count")
sns.catplot(x="veil-color", data=df, kind="count")
sns.catplot(x="ring-number", data=df, kind="count")
sns.catplot(x="ring-type", data=df, kind="count")
sns.catplot(x="spore-print-color", data=df,  kind="count")
sns.catplot(x="population", data=df, kind="count")
sns.catplot(x="habitat", data=df, kind="count")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %% [markdown]
# ##  2.  DRAW IRIS DISTRIBUTION

# %% [markdown]
# ### Show the data distribution by value frequency of every feature IRIS

# %%
sns.catplot(x="sepal_length", data=df_i, kind="count")
arr = np.array(df_i['sepal_length'])
print("sepal_length mean : ", np.mean(arr)) 
print("sepal_length standard_deviation : ", np.std(arr)) 

sns.catplot(x="sepal_width", data=df_i, kind="count")
arr = np.array(df_i['sepal_width'])
print("sepal_width mean : ", np.mean(arr)) 
print("sepal_width standard_deviation : ", np.std(arr)) 

sns.catplot(x="petal_length", data=df_i, kind="count")
arr = np.array(df_i['petal_length'])
print("petal_length mean : ", np.mean(arr)) 
print("petal_length standard_deviation : ", np.std(arr)) 

sns.catplot(x="petal_width", data=df_i, kind="count")
arr = np.array(df_i['petal_width'])
print("petal_width mean : ", np.mean(arr)) 
print("petal_width standard_deviation : ", np.std(arr)) 

sns.catplot(x="species", data=df_i, kind="count")
plt.show()
# Out:
# sepal_length mean :  5.843333333333334
# sepal_length standard_deviation :  0.8253012917851409
# sepal_width mean :  3.0540000000000003
# sepal_width standard_deviation :  0.4321465800705435
# petal_length mean :  3.758666666666666
# petal_length standard_deviation :  1.7585291834055212
# petal_width mean :  1.1986666666666668
# petal_width standard_deviation :  0.7606126185881716

# %% [markdown]
# ## code explain
# use catplot(column,data,counts) to plot the histrogram
# use numpy to choose the column and use function mean() and std() to caculate mean value and standard deviation

# %% [markdown]
# ### Split data based on their labels (targets) and show the data distribution of each feature again mushroom

# %%
sns.catplot(x="cap-shape", data=df, col="poisonous",kind="count")
sns.factorplot(x="cap-surface", data=df, col="poisonous",kind="count")
sns.factorplot(x="cap-color", data=df,col="poisonous", kind="count")
sns.factorplot(x="bruises?", data=df, col="poisonous", kind="count")
sns.factorplot(x="odor", data=df,col="poisonous", kind="count")
sns.factorplot(x="gill-attachment", data=df,  col="poisonous",kind="count")
sns.factorplot(x="gill-spacing", data=df, col="poisonous", kind="count")
sns.factorplot(x="gill-size", data=df, col="poisonous", kind="count")
sns.factorplot(x="gill-color", data=df, col="poisonous", kind="count")
sns.factorplot(x="stalk-shape", data=df, col="poisonous", kind="count")
sns.factorplot(x="stalk-root", data=df,col="poisonous", kind="count")
sns.factorplot(x="stalk-surface-above-ring", data=df,col="poisonous", kind="count")
sns.factorplot(x="stalk-surface-below-ring", data=df,col="poisonous", kind="count")
sns.factorplot(x="stalk-color-above-ring", data=df,col="poisonous", kind="count")
sns.factorplot(x="stalk-color-below-ring", data=df,col="poisonous", kind="count")
sns.factorplot(x="veil-type", data=df,col="poisonous", kind="count")
sns.factorplot(x="veil-color", data=df, col="poisonous",kind="count")
sns.factorplot(x="ring-number", data=df,col="poisonous", kind="count")
sns.factorplot(x="ring-type", data=df, col="poisonous",kind="count")
sns.factorplot(x="spore-print-color", data=df, col="poisonous", kind="count")
sns.factorplot(x="population", data=df, col="poisonous",kind="count")
sns.factorplot(x="habitat", data=df,col="poisonous", kind="count")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### Split data based on their labels (targets) and show the data distribution of each feature again mushroom

# %%
sns.catplot(x="sepal_length", data=df_i,col="species", kind="count")

sns.catplot(x="sepal_width", data=df_i, col="species",kind="count")

sns.catplot(x="petal_length", data=df_i,col="species", kind="count")

sns.catplot(x="petal_width", data=df_i,col="species", kind="count")

plt.show()

# %% [markdown]
# ## code exaplain
#
# use the same function in 2-2 but add col="lables" to split the by lables

# %% [markdown]
# ## 3 . DATA PREPROCESSING MUSHROOM

# %% [markdown]
# ### DROP FEATURES WITH MISSING VALUE (MUSHROOM)

# %%
df = df.drop(columns = df.columns[(df=="?").any()])

# %% [markdown]
# ### DROP FEATURES (IRIS)

# %%
df_i = df_i.drop(columns = df_i.columns[(df_i=="?").any()])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %% [markdown]
# ## code explain
# use dataframe.drop to drop columns who have '?' in it

# %% [markdown]
# ### TRANSFORM DATA FORMAT MUSHROOM

# %%
df_origin = df
df = pd.get_dummies(df)
Y = df.iloc[:,0]
X = df.iloc[:,2:]

# %% [markdown]
# ### TRANSFORM DATA FORMAT IRIS

# %%
X_i = data_i.iloc[:,:4].values   # 0~4 column
Y_i = data_i['species'].values   # species column

# %% [markdown]
# ## code explain
# use get_dummies to turn mushroom dataset's alphabet data to numeric data <br>
# split data into X which is the conditional columns and Y which is the result columns<br>

# %% [markdown]
# ### SHUFFLE DATA MUSHROOM

# %%
from sklearn.utils import shuffle
df = shuffle(df , random_state=0)

# %% [markdown]
# ### SHUFFLE DATA IRIS

# %%
from sklearn.utils import shuffle
df_i = shuffle(df_i , random_state=0)

# %% [markdown]
# ## code explain
# import shuffle from sklearn.utils to shuffle the data

# %% [markdown]
# ## 4. MODEL CONSTRUCTION MUSHROOM

# %%
from sklearn.naive_bayes import CategoricalNB
from sklearn.naive_bayes import MultinomialNB

mnb_laplace = CategoricalNB(alpha=1)
mnb_nolaplace = CategoricalNB(alpha = 1.0e-10)

# %% [markdown]
# ## 4. MODEL CONSTRUCTION IRIS

# %%
from sklearn.naive_bayes import GaussianNB
nvclassifier = GaussianNB()

# %% [markdown]
# ## code explain
#
# from sklearn.naive_bayes import CategoricalNB and GaussianNB <br>
# notice that CategoricalNB applies laplace smoothing when the argument aplha is not zero <br>

# %% [markdown]
# ## 5. TRAIN TEST SPLIT MUSHROOM

# %%
X_train_list = []
Y_train_list = []
X_test_list = []
Y_test_list = []

# K-fold cross-validation
from sklearn.model_selection import KFold
cv = KFold(n_splits=3 , random_state=1, shuffle=True)

for train_index, test_index in cv.split(X, Y):
    X_train_list.append(X.iloc[train_index])
    X_test_list.append(X.iloc[test_index])
    Y_train_list.append(Y[train_index])
    Y_test_list.append(Y[test_index])
    
# hold out splitting data into 70% training and 30% test data: 
# test_size or train_size is the ratio
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=787)

# %% [markdown]
# ## 5. TRAIN TEST SPLIT IRIS

# %%
# last column (output column)
# holdout validation
Xi_train_list = []
Yi_train_list = []
Xi_test_list = []
Yi_test_list = []


from sklearn.model_selection import train_test_split
Xi_train, Xi_test, yi_train, yi_test = train_test_split(X_i, Y_i, test_size = 0.3, random_state = 82)

# K-fold cross-validation
from sklearn.model_selection import KFold
kf = KFold(n_splits=3 , random_state=0, shuffle=True)

for train_index, test_index in kf.split(X_i, Y_i):
    Xi_train_list.append(X_i[train_index])
    Xi_test_list.append(X_i[test_index])
    Yi_train_list.append(Y_i[train_index])
    Yi_test_list.append(Y_i[test_index])

# %% [markdown]
# ## code explain
#
# Split the data into conditional test and train data and result train and test data
#
# Hold out validation : import train_test_split to split the data<br>
# test_size=0.3 means that after splitting,(test size/all size) = 0.3. Which is equal to (train_size : test_size) = 7:3<br>
# <br>
# K-Fold validation : import KFold to split the data, and then use for loop to append those data into train_list and test_list.<br>

# %% [markdown]
# ## 6. RESULTS MUSHROOM

# %% [markdown]
# ### hold-out with laplace

# %%
mnb_laplace.fit(X_train, y_train)
y_pred = mnb_laplace.predict(X_test) 
pre = precision_score(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
recall = recall_score(y_test, y_pred, average='macro')

print(cm)
print("\n")
print('Hold out splitting Accuracy with laplace: {:.4f}'.format(acc))
print('Hold out splitting Precision with laplace: {:.4f}'.format(pre))
print('Hold out splitting Sensitivity with laplace: {:.4f}'.format(recall))
print("\n")
print(classification_report(y_test, y_pred))
# Out:
# [[1092  121]
#  [  16 1208]]
#
#
# Hold out splitting Accuracy with laplace: 0.9438
# Hold out splitting Precision with laplace: 0.9090
# Hold out splitting Sensitivity with laplace: 0.9436
#
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94      1213
#            1       0.91      0.99      0.95      1224
#
#     accuracy                           0.94      2437
#    macro avg       0.95      0.94      0.94      2437
# weighted avg       0.95      0.94      0.94      2437

# %% [markdown]
# ### hold out without laplace

# %%
mnb_nolaplace.fit(X_train, y_train)
y_pred = mnb_nolaplace.predict(X_test) 
acc = accuracy_score(y_test, y_pred)
pre = precision_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
recall = recall_score(y_test, y_pred, average='macro')
print(cm)
print('Hold out splitting Accuracy without laplace: {:.4f}'.format(acc))
print('Hold out splitting Precision without laplace: {:.4f}'.format(pre))
print('Hold out splitting Sensitivity without laplace: {:.4f}'.format(recall))
print("\n")
print(classification_report(y_test, y_pred))
# Out:
# [[1211    2]
#  [  11 1213]]
# Hold out splitting Accuracy without laplace: 0.9947
# Hold out splitting Precision without laplace: 0.9984
# Hold out splitting Sensitivity without laplace: 0.9947
#
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1213
#            1       1.00      0.99      0.99      1224
#
#     accuracy                           0.99      2437
#    macro avg       0.99      0.99      0.99      2437
# weighted avg       0.99      0.99      0.99      2437

# %% [markdown]
# ### Kfold with laplace

# %%
accuracy = 0
precision = 0
recall = 0

for i in range(3):
    
    mnb_laplace.fit(X_train_list[i], Y_train_list[i])
    y_pred = mnb_laplace.predict(X_test_list[i]) 
    precision += precision_score(Y_test_list[i], y_pred)
    accuracy += accuracy_score(Y_test_list[i], y_pred)
    recall += recall_score(Y_test_list[i], y_pred, average='macro')
    cm = confusion_matrix(Y_test_list[i], y_pred)
    print(cm)
    print("\n")

print('K-FOLD splitting Accuracy with laplace: {:.4f}'.format(accuracy/3))
print('K-FOLD splitting Precision with laplace: {:.4f}'.format(precision/3))
print('K-FOLD splitting Sensitivity with laplace : {:.4f}'.format(recall/3))
print("\n")

score = cross_val_predict(mnb_laplace, X, Y, cv=cv)
score.shape
print(classification_report(Y, score))
print("\n")
# Out:
# [[1207  117]
#  [  11 1373]]
#
#
# [[1165  142]
#  [  25 1376]]
#
#
# [[1163  121]
#  [  16 1407]]
#
#
# K-FOLD splitting Accuracy with laplace: 0.9468
# K-FOLD splitting Precision with laplace: 0.9162
# K-FOLD splitting Sensitivity with laplace : 0.9453
#
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94      3915
#            1       0.92      0.99      0.95      4208
#
#     accuracy                           0.95      8123
#    macro avg       0.95      0.95      0.95      8123
# weighted avg       0.95      0.95      0.95      8123

# %% [markdown]
# ### Kfold without laplace

# %%
accuracy = 0
precision = 0
recall = 0

for i in range(3):

    mnb_nolaplace.fit(X_train_list[i], Y_train_list[i])
    y_pred = mnb_nolaplace.predict(X_test_list[i]) 
    precision += precision_score(Y_test_list[i], y_pred)
    accuracy += accuracy_score(Y_test_list[i], y_pred)
    recall += recall_score(Y_test_list[i], y_pred, average='macro')
    cm = confusion_matrix(Y_test_list[i], y_pred)
    print(cm)
    print("\n")

print('K-FOLD splitting Accuracy without laplace: {:.4f}'.format(accuracy/3))
print('K-FOLD splitting Precision without laplace: {:.4f}'.format(precision/3))
print('K-FOLD splitting Sensitivity without laplace : {:.4f}'.format(recall/3))
score = cross_val_predict(mnb_nolaplace, X, Y, cv=cv)
score.shape
print(classification_report(Y, score))
print("\n")
# Out:
# [[1323    1]
#  [  11 1373]]
#
#
# [[1306    1]
#  [  19 1382]]
#
#
# [[1283    1]
#  [  12 1411]]
#
#
# K-FOLD splitting Accuracy without laplace: 0.9945
# K-FOLD splitting Precision without laplace: 0.9993
# K-FOLD splitting Sensitivity without laplace : 0.9946
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3915
#            1       1.00      0.99      0.99      4208
#
#     accuracy                           0.99      8123
#    macro avg       0.99      0.99      0.99      8123
# weighted avg       0.99      0.99      0.99      8123

# %% [markdown]
# ## 6. RESULTS IRIS

# %% [markdown]
# ### Hold out validation

# %%
nvclassifier.fit(Xi_train, yi_train)
y_pred = nvclassifier.predict(Xi_train)
pre = precision_score(yi_test, y_pred, average='micro')
acc = accuracy_score(yi_test, y_pred)
cm = confusion_matrix(yi_test, y_pred)
recall = recall_score(yi_test, y_pred, average='macro')

print(cm)
print("\n")
print('Hold out splitting Accuracy : {:.4f}'.format(acc))
print('Hold out splitting Precision : {:.4f}'.format(pre))
print('Hold out splitting Sensitivity : {:.4f}'.format(recall))
print(classification_report(yi_test, y_pred))
# Out:
# [[18  0  0]
#  [ 0 10  1]
#  [ 0  2 14]]
#
#
# Hold out splitting Accuracy : 0.9333
# Hold out splitting Precision : 0.9333
# Hold out splitting Sensitivity : 0.9280
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.83      0.91      0.87        11
#  Iris-virginica       0.93      0.88      0.90        16
#
#        accuracy                           0.93        45
#       macro avg       0.92      0.93      0.92        45
#    weighted avg       0.94      0.93      0.93        45

# %% [markdown]
# ### Kfold validation

# %%
from sklearn.model_selection import cross_val_score
# evaluate a logistic regression model using k-fold cross-validation
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_predict
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report


acc = 0
pre = 0
recall = 0
Y_PRED = []
Y_TEST = []

for i in range(3):
  
    nvclassifier.fit(Xi_train_list[i], Yi_train_list[i])
    y_pred = nvclassifier.predict(Xi_test_list[i])
    Y_PRED.append(y_pred)
    Y_TEST.append(Yi_test_list[i])
    pre += precision_score(Yi_test_list[i], y_pred, average='micro')
    acc += accuracy_score(Yi_test_list[i], y_pred)
    recall += recall_score(Yi_test_list[i], y_pred, average='macro')
    cm = confusion_matrix(Yi_test_list[i], y_pred)
    print(cm)
    print("\n")

print('K-FOLD splitting Accuracy : {:.4f}'.format(acc/3))
print('K-FOLD splitting Precision : {:.4f}'.format(pre/3))
print('K-FOLD splitting Sensitivity : {:.4f}'.format(recall/3))
print('\n')

score = cross_val_predict(nvclassifier, X_i, Y_i, cv=kf)
score.shape
print(classification_report(Y_i, score))
print('\n')
# Out:
# [[16  0  0]
#  [ 0 19  0]
#  [ 0  2 13]]
#
#
# [[15  0  0]
#  [ 0 14  0]
#  [ 0  2 19]]
#
#
# [[19  0  0]
#  [ 0 15  2]
#  [ 0  0 14]]
#
#
# K-FOLD splitting Accuracy : 0.9600
# K-FOLD splitting Precision : 0.9600
# K-FOLD splitting Sensitivity : 0.9615
#
#
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        50
# Iris-versicolor       0.92      0.96      0.94        50
#  Iris-virginica       0.96      0.92      0.94        50
#
#        accuracy                           0.96       150
#       macro avg       0.96      0.96      0.96       150
#    weighted avg       0.96      0.96      0.96       150

# %% [markdown]
# ## code explain
#
# choose the model you want (guassNB, categoricalNB with or withour laplace)
#
# model.fit(X_train, y_train) --> use train data to fit the data <br>
# y_pred = model.predict(X_test) --> predict y_pred by getting X-test <br>
# then compare y_test(result) with y_pred (predict result) <br>
# precision_score(y_test, y_pred)--> get precision <br>
# accuracy_score(y_test, y_pred) --> get accuracy <br>
# confusion_matrix(y_test, y_pred) --> get confusion matrix <br>
# recall_score(y_test, y_pred, average='macro') --> get sensitivity <br>
#
#
# For K-Hold , after spliting data into 3 parts, choose two parts to be training data and one part to be the test data in every loop. Then do the same thing above.

# %% [markdown]
# ## 7. COMPARSION AND CONCLUSION

# %% [markdown]
# ### K fold compare vs Hold out validation
# In conclusion, K-fold is a little bit more accurate than Hold-out validation. Hold out's performance evaluation is subject to higher variance given the smaller size of the data. However,K-fold validation is more time consuming to train and test model. So choosing a k is also choosing between time and acuuracy.
#
# ### Laplace smoothing with and without
# laplace smoothing can make the worst case (may have zero on one feature so when multiplying it will turn out to be zero which we don't want) better. However, the accuracy depends on the alpha we choose (maybe better or worse).

# %% [markdown]
# ## 8. Questions

# %% [markdown]
# ### 1.Show P(Xstalk−color−below−ring|Y=e) with and without Laplace smoothing by histograms

# %% [markdown]
# #### WITHOUT LAPLACE

# %%
e_total = df_origin.loc[(df_origin['poisonous'] == 'e')].count()[0]

color_list = ['n','b','c','g','o','p','e','w','y']
color_p_list = []
for color in color_list:
    x_conditional = df_origin.loc[( df_origin['poisonous'] == 'e') & ( df_origin['stalk-color-below-ring'] == color)].count()[0]
    c_p = x_conditional/e_total
    color_p_list.append(c_p)
    plt.plot(color, c_p,color='b')

plt.bar(color_list, color_p_list)
plt.show()

# %% [markdown]
# ## code explain
#
# P(Xstalk−color−below−ring|Y=e) = N(Xstalk−color−below−ring & Y=e) / N(Y=e) <br>
#
# N(Y=e)  = e_total<br>
# N(Xstalk−color−below−ring & Y=e) = x_conditional<br><br>
#
# df_origin.loc[( df_origin['poisonous'] == 'e') & ( df_origin['stalk-color-below-ring'] == color)].count()[0]<br>
# means that count the total number of the poisonous column whoose value = 'e' and stalk-color-below-ring column whoose value = color(one of the color_list)<br>
# use for loop to count each color<br>

# %% [markdown]
# #### WITH LAPLACE

# %%
color_list = ['n','b','c','g','o','p','e','w','y']
k = 5
m= len(color_list)
color_p_list = []
for color in color_list:
    x_conditional = df_origin.loc[( df_origin['poisonous'] == 'e') & ( df_origin['stalk-color-below-ring'] == color)].count()[0]
    c_p = (x_conditional+k)/(e_total+k*m)
    #print(c_p)
    color_p_list.append(c_p)
    plt.plot(color, c_p,color='b')

plt.bar(color_list, color_p_list)
plt.show()

# %% [markdown]
# ## code explain
#
# P(Xstalk−color−below−ring|Y=e) with laplace = (N(Xstalk−color−below−ring & Y=e)+k) / (N(Y=e)+k*m)<br><br>
#
# m = color_list's len<br>
# k : I choose it because the spec did not specify<br>
# N(Y=e)  = e_total<br>
# N(Xstalk−color−below−ring & Y=e) = x_conditional<br>

# %% [markdown]
# ### 2-1 What are the values of μ and σ of assumed P(Xpetal_length|Y=Iris Versicolour)?

# %%
mu = df_i.loc[( df_i['species'] == 'Iris-versicolor')]['petal_length'].mean()
sigma = df_i.loc[( df_i['species'] == 'Iris-versicolor')]['petal_length'].std()
print('mean = ',mu)
print('sigma = ',sigma)
# Out:
# mean =  4.26
# sigma =  0.46991097723995806

# %% [markdown]
# ## code explain
#
# count the mean and standard deviation by choosing the rows whoose 'species' column's value is 'Iris-versicolor'.<br>
# df_i.loc[( df_i['species'] == 'Iris-versicolor')] <br>
#
# then get the 'petal_lenght' row and count their mean and std by mean(), std().<br>
# ['petal_length'].mean()<br>
# ['petal_length'].std()

# %% [markdown]
# ### 2-2 Use a graph to show the probability density function of assumed P(Xpetal_length|Y=Iris Versicolour)

# %%
import scipy.stats as stats

x = np.linspace(mu - 3*sigma, mu + 3*sigma, 10000)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %% [markdown]
# ## code explain
#
# use linespace to split mu - 3*sigma ~ mu + 3*sigma into 10000 points<br>
# and then draw the normal distribution by stats.norm.pdf using the mean and standard deviation above
